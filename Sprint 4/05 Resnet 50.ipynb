# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(
    include_top= True,
    weights='imagenet',
    input_tensor=None,
    input_shape=None,
    pooling=None
)

# %%
img_path = 'pes.jpg'
img = tf.keras.preprocessing.image.load_img(img_path ,target_size=(224, 224))
x = tf.keras.preprocessing.image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = tf.keras.applications.resnet50.preprocess_input(x) 

preds = model.predict(x)
print('Predicted:', tf.keras.applications.resnet50.decode_predictions(preds, top=5)[0])
# Out:
# 1/1 [==============================] - 0s 85ms/step
# Predicted: [('n02099712', 'Labrador_retriever', 0.6415706), ('n02087394', 'Rhodesian_ridgeback', 0.1672509), ('n02099601', 'golden_retriever', 0.15405715), ('n02109047', 'Great_Dane', 0.01368881), ('n02090379', 'redbone', 0.0055767526)]
